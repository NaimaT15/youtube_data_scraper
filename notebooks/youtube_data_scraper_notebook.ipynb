# %%
import pandas as pd
import sys
import os
from dotenv import load_dotenv

# Add the scripts directory to the Python path
sys.path.append(os.path.abspath('../scripts'))

# Load environment variables from .env file
load_dotenv()

# Get the API key from the environment variable
API_KEY = os.getenv("YOUTUBE_API_KEY")

if not API_KEY:
    raise ValueError("YOUTUBE_API_KEY environment variable not set.")
else:
    print("API key loaded successfully!")
# Out:
# API key loaded successfully!

# %%
from youtube_data_scraper import fetch_youtube_data


# Define the genre and call the function
genre = "Education"  # Replace with desired genre
data = fetch_youtube_data(API_KEY, genre, max_results=500)

# Display a preview of the data
import pandas as pd
df = pd.DataFrame(data)
print(df.head())
# Out:
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
# c:\Users\Naim\still-traveling-assignment\scripts\youtube_data_scraper.py:49: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('en')
